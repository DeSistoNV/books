# %%
import pandas as pd
import matplotlib.pyplot as plt
# %pylab inline
plt.style.use('ggplot')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
x = pd.read_csv('/home/nick/data.csv')
x
# Out:
#     lambda  yellow  red  standard   r(yellow)     r(red)
# 0      470     210  152       834   21.706399  14.429109
# 1      525     770  158       901   84.837963  14.004630
# 2      560     847  236       887   95.294118  23.411765
# 3      585     972  449       970  100.214362  44.158628
# 4      600     973  658       966  100.753498  66.846071
# 5      645     950  888       944  100.661521  93.825799
# 6      700     913  879       909  100.458716  96.559633
# 7      735     930  890       939   99.002217  94.567627
# 8      810     818  803       832   98.238994  96.352201
# 9      880     916  849       926   98.875141  91.338583
# 10     940     870  852       884   98.347107  96.221960

# %%
fig = plt.figure(figsize=(20,8))
plt.plot(x['lambda'],x['r(yellow)'],'y',marker='H',label='Yellow Paper')
plt.plot(x['lambda'],x['r(red)'],'r',marker='H',label='Red Paper')
plt.title('Yellow Paper',size=20)
plt.legend()
ylabel('% Reflectivity',size=20)
xlabel('$\lambda$',size=20)
xticks(x['lambda'])
plt.axvline(620,color='red',lw=2,alpha=1)
plt.axvline(750,color='red',lw=2,alpha=1)
plt.axvline(597,color='yellow',lw=2,alpha=1)
plt.axvline(577,color='yellow',lw=2,alpha=1)
