# %%
% pylab inline

from scipy import ndimage as nd
from scipy.misc import imresize
from scipy.signal import convolve2d

from skimage import data
from skimage.util import img_as_float
from skimage.filters import gabor_kernel
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Gabor Kernels
#  * theta : Orientation in radians. If 0, the harmonic is in the x-direction.
#
#  * frequency : Spatial frequency of the harmonic function. Specified in pixels.
#
#  * sigma :  Standard deviation in x- and y-directions. These directions apply to the kernel before rotation. If theta = pi/2, then the kernel is rotated 90 degrees so that sigma_x controls the vertical direction.

# %%
# prepare filter bank kernels
kernels = []
thetas = [pi * d / 180 for d in np.linspace(0,157.5,8)] # degrees -> radians
for theta in thetas: # 
    for sigma in (1, 3):
        for frequency in [1]: 
            kernel = np.real(gabor_kernel(frequency, theta=theta,
                                          sigma_x=sigma, sigma_y=sigma))
            kernels.append(kernel)
plt.figure(figsize=(20,10))            
for k in np.array(kernels):
    plt.plot(k)
plt.title("Gabor Kernels")

# %%
# Plot a selection of the filter bank kernels and their responses.
results = []
kernel_params = []
for theta in thetas:
    for frequency in [.01]:
        kernel = gabor_kernel(frequency, theta=theta)
        params = 'theta=%d,\nfrequency=%.2f' % (theta * 180 / np.pi, frequency)
        kernel_params.append(params)
        # Save kernel and the power image for each image
        results.append(kernel)

# %%
def gabor_block(gabor,grid_len=2):
    x = np.hstack((gabor,np.zeros((gabor.shape))))
    x = np.vstack((x,np.zeros((x.shape))))
    return x


fig= plt.subplots(nrows=1, ncols=len(thetas), figsize=(18, 10))
plt.gray()

for label, kernel, i in zip(kernel_params, results,np.arange(len(kernels))):
    ax = plt.subplot(2,len(thetas),i+1)
    ax.imshow(np.real(kernel), interpolation='nearest')
    ax.set_title(label, fontsize=10)
    ax.set_xticks([])
    ax.set_yticks([])
    ax = plt.subplot(2,len(thetas),i+len(thetas)+1)
    ax.imshow(gabor_block(np.real(kernel)))

# %%
# def power(image, kernel):
#     # Normalize images for better comparison.
#     image = (image - image.mean()) / image.std()
#     return np.sqrt(nd.convolve(image, np.real(kernel), mode='wrap')**2 +
#                    nd.convolve(image, np.imag(kernel), mode='wrap')**2)

# new = np.zeros((300,300),dtype='float')
# imshow(power(new,results[0]))
# Out:
# /home/nick/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:3: RuntimeWarning: invalid value encountered in divide
#   app.launch_new_instance()
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-5-096f9673fc08> in <module>()
#       6
#       7 new = np.zeros((300,300),dtype='float')
# ----> 8 imshow(power(new,results[0]))
#
# <ipython-input-5-096f9673fc08> in power(image, kernel)
#       2     # Normalize images for better comparison.
#       3     image = (image - image.mean()) / image.std()
# ----> 4     return np.sqrt(nd.convolve(image, np.real(kernel), mode='wrap')**2 +
#       5                    nd.convolve(image, np.imag(kernel), mode='wrap')**2)
#       6
#
# /home/nick/anaconda/lib/python2.7/site-packages/scipy/ndimage/filters.pyc in convolve(input, weights, output, mode, cval, origin)
#     694     """
#     695     return _correlate_or_convolve(input, weights, output, mode, cval,
# --> 696                                   origin, True)
#     697
#     698
#
# /home/nick/anaconda/lib/python2.7/site-packages/scipy/ndimage/filters.pyc in _correlate_or_convolve(input, weights, output, mode, cval, origin, convolution)
#     542     output, return_value = _ni_support._get_output(output, input)
#     543     mode = _ni_support._extend_mode_to_code(mode)
# --> 544     _nd_image.correlate(input, weights, output, mode, cval, origins)
#     545     return return_value
#     546
#
# MemoryError:
